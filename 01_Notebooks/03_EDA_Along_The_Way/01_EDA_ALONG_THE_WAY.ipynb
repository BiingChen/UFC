# %%
import pandas as pd

# %%
# !ls ../../02_Data/02_Processed_Data/
# Out:
# V1_Fight_Fighters_FighterInfo.csv
# V1_Fight_Fighters_FighterInfo_w_flipped.csv
# V2_Fight_Details.csv
# df_ems.csv
# fighter_static_stats.csv
# train.csv

# %%
df = pd.read_csv('../../02_Data/02_Processed_Data/V2_Fight_Details_Munged0711.csv', index_col=0)

# %%
df.columns
# Out:
# Index(['currentrnd', 'eventid', 'fightid', 'maxrnds', 'timestamp',
#        'f1_body_significant_strikes_attempts',
#        'f1_body_significant_strikes_landed', 'f1_body_total_strikes_attempts',
#        'f1_body_total_strikes_landed', 'f1_clinch_body_strikes_attempts',
#        ...
#        'distance_body_strikes_landed_diff',
#        'clinch_body_strikes_attempts_diff', 'grappling_takedowns_landed_diff',
#        'head_significant_strikes_attempts_diff',
#        'legs_total_strikes_attempts_diff',
#        'body_significant_strikes_landed_diff',
#        'ground_leg_strikes_attempts_diff',
#        'distance_body_strikes_attempts_diff',
#        'head_significant_strikes_landed_diff', 'date'],
#       dtype='object', length=202)

# %%
diff_cols = [col for col in df.columns if 'diff' in col]
diff_cols[:5]
# Out:
# ['distance_strikes_attempts_diff',
#  'clinch_leg_strikes_landed_diff',
#  'grappling_submissions_attempts_diff',
#  'ground_total_strikes_attempts_diff',
#  'head_total_strikes_attempts_diff']

# %%
df[diff_cols].
# Out:
#        distance_strikes_attempts_diff  clinch_leg_strikes_landed_diff  \
# count                    4.774000e+03                    4.774000e+03
# mean                     8.197604e-19                    1.860449e-19
# std                      2.594652e-01                    4.990850e-01
# min                     -1.000000e+00                   -1.000000e+00
# 25%                     -1.551879e-01                    0.000000e+00
# 50%                      0.000000e+00                    0.000000e+00
# 75%                      1.551879e-01                    0.000000e+00
# max                      1.000000e+00                    1.000000e+00
#
#        grappling_submissions_attempts_diff  \
# count                         4.774000e+03
# mean                         -4.651123e-20
# std                           6.001702e-01
# min                          -1.000000e+00
# 25%                           0.000000e+00
# 50%                           0.000000e+00
# ...

# %%
import seaborn as sns

# %%
sns.boxplot()
