# %% [markdown]
# # Modeling

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegressionCV, LogisticRegression
import pickle

# %% [markdown]
# ## Read in the training and test data

# %%
with open('../../02_Data/02_Processed_Data/X_train.pkl', 'rb') as f:
    X_train = pickle.load(f)
    
with open('../../02_Data/02_Processed_Data/y_train.pkl', 'rb') as f:
    y_train = pickle.load(f)    

with open('../../02_Data/02_Processed_Data/X_test.pkl', 'rb') as f:
    X_test = pickle.load(f)
    
with open('../../02_Data/02_Processed_Data/y_test.pkl', 'rb') as f:
    y_test = pickle.load(f)

# %% [markdown]
# ## Build some models

# %%
lr = LogisticRegression(penalty='l1', C=0.1, max_iter=200)
lr.fit(X_train, y_train)
print('Train:', lr.score(X_train,y_train))
print('Test:', lr.score(X_test,y_test))

# %%
lr = LogisticRegression(penalty='l1', C=0.1, max_iter=1000)
lr.fit(X_train, y_train)
print('Train:', lr.score(X_train,y_train))
print('Test:', lr.score(X_test,y_test))

# %%
pd.DataFrame(lr.coef_, columns=X_train.columns).T.sort_values(0, ascending=False)
# Out:
#                                                       0
# f1_head_significant_strikes_landed_diff_em     0.146705
# f1_grappling_submissions_attempts_diff_em      0.132935
# f2_f2_distance_body_strikes_landed_em          0.092586
# f2_f2_clinch_head_strikes_landed_em            0.088485
# f1_f1_grappling_takedowns_attempts_em          0.065554
# f1_f2_distance_body_strikes_attempts_em        0.061498
# f1_body_significant_strikes_attempts_diff_em   0.051938
# f1_stance                                      0.049905
# f2_f2_clinch_body_strikes_attempts_em          0.039569
# f2_f1_clinch_significant_strikes_attempts_em   0.039033
# f2_f2_ground_body_strikes_landed_em            0.038776
# f2_f1_ground_head_strikes_landed_em            0.037338
# f2_f2_grappling_submissions_attempts_em        0.037009
# f1_f1_clinch_head_strikes_attempts_em          0.036365
# f1_f1_clinch_body_strikes_attempts_em          0.034030
# f1_f1_grappling_takedowns_landed_em            0.032099
# f1_f2_grappling_takedowns_attempts_em          0.029424
# f1_f2_clinch_significant_strikes_landed_em     0.027585
# f1_significant_strikes_attempts_diff_em        0.027472
# f1_f1_knock_down_landed_em                     0.026589
# f1_f1_distance_body_strikes_landed_em          0.022995
# f1_ground_body_strikes_landed_diff_em          0.021775
# f2_f2_ground_head_strikes_landed_em            0.021388
# f2_f1_distance_leg_strikes_attempts_em         0.020490
# f1_f1_ground_total_strikes_landed_em           0.018445
# f1_f2_clinch_total_strikes_landed_em           0.016406
# f1_height                                      0.016213
# f1_f1_ground_significant_strikes_attempts_em   0.014746
# f1_f1_significant_strikes_landed_em            0.014345
# f2_f2_ground_total_strikes_landed_em           0.013711
# ...                                                 ...
# f1_f1_clinch_total_strikes_landed_em          -0.011762
# f2_f2_ground_significant_strikes_attempts_em  -0.013431
# f2_f1_ground_total_strikes_landed_em          -0.014292
# f1_f1_ground_total_strikes_attempts_em        -0.014868
# f1_f1_body_total_strikes_attempts_em          -0.016724
# f2_f1_ground_head_strikes_attempts_em         -0.016868
# f2_height                                     -0.018371
# f2_f2_clinch_significant_strikes_landed_em    -0.019731
# f1_f2_ground_head_strikes_landed_em           -0.022471
# f2_f1_clinch_body_strikes_landed_em           -0.023382
# f2_f2_grappling_takedowns_attempts_em         -0.023914
# f1_f1_distance_leg_strikes_attempts_em        -0.025274
# f2_f1_significant_strikes_landed_em           -0.025590
# f1_f1_clinch_significant_strikes_attempts_em  -0.027483
# f2_f1_knock_down_landed_em                    -0.027694
# f2_f2_clinch_total_strikes_landed_em          -0.027826
# f2_f1_grappling_takedowns_landed_em           -0.028210
# f2_ground_significant_strikes_percent_diff_em -0.031285
# f1_f1_ground_head_strikes_landed_em           -0.033988
# f1_f2_ground_body_strikes_landed_em           -0.037741
# f1_f2_clinch_body_strikes_attempts_em         -0.038088
# f2_body_significant_strikes_attempts_diff_em  -0.040308
# f2_f2_distance_body_strikes_attempts_em       -0.051817
# f2_f1_clinch_head_strikes_attempts_em         -0.058741
# f2_grappling_submissions_attempts_diff_em     -0.061129
# f2_f1_grappling_takedowns_attempts_em         -0.061197
# f2_stance                                     -0.063618
# f1_f2_clinch_head_strikes_landed_em           -0.088813
# f1_f2_distance_body_strikes_landed_em         -0.096793
# f2_head_significant_strikes_landed_diff_em    -0.157327
#
# [436 rows x 1 columns]

# %%
rf = RandomForestClassifier(n_estimators=1000, max_depth=3, min_samples_split=2)
rf.fit(X_train, y_train)
print('Train:', rf.score(X_train,y_train))
print('Test:',rf.score(X_test,y_test))
# Out:
# Train: 0.6875
# Test: 0.6019607843137255

# %%
rf = RandomForestClassifier()
rf_params = {
    'n_estimators': [10, 50, 500],
    'min_samples_split': [2,3],
    'min_samples_leaf': [1,2]
}
gs = GridSearchCV(rf, param_grid=rf_params)
gs.fit(X_train, y_train)
print('Best Score:', gs.best_score_)
print('Best Parameters:', gs.best_params_)
print('Test:',gs.score(X_test,y_test))
# Out:
# Best Score: 0.5528846153846154
# Best Parameters: {'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500}
# Test: 0.5901960784313726

# %%
rf = RandomForestClassifier()
rf_params = {
    'n_estimators': [1000],
    'min_samples_split': [2,3],
    'max_depth': [3,5,10]
}
gs = GridSearchCV(rf, param_grid=rf_params)
gs.fit(X_train, y_train)
print('Best Score:', gs.best_score_)
print('Best Parameters:', gs.best_params_)
print('Test:',gs.score(X_test,y_test))
# Out:
# Best Score: 0.566198224852071
# Best Parameters: {'max_depth': 3, 'min_samples_split': 3, 'n_estimators': 1000}
# Test: 0.6078431372549019

# %%
pd.DataFrame(rf.feature_importances_, index=X_train.columns).sort_values(0, ascending=False)
# Out:
#                                                        0
# f1_significant_strikes_landed_diff_avg          0.012945
# f1_head_significant_strikes_landed_avg_diff     0.011565
# f2_head_significant_strikes_landed_diff_avg     0.010678
# f2_head_significant_strikes_percent_avg_diff    0.009419
# f2_significant_strikes_attempts_diff_avg        0.008538
# f1_f2_clinch_head_strikes_percent_avg           0.008459
# f2_significant_strikes_landed_diff_avg          0.008045
# f1_distance_head_strikes_landed_avg_diff        0.007903
# f2_distance_head_strikes_landed_diff_avg        0.007468
# f1_distance_head_strikes_landed_diff_avg        0.007286
# f1_head_significant_strikes_attempts_diff_avg   0.007019
# f2_ground_head_strikes_percent_avg_diff         0.006868
# f2_significant_strikes_percent_avg_diff         0.006832
# f1_grappling_takedowns_percent_avg_diff         0.006762
# f1_distance_strikes_landed_diff_avg             0.006743
# f2_f2_significant_strikes_percent_avg           0.006685
# f2_head_total_strikes_percent_avg_diff          0.006557
# reach_height_ratio_diff                         0.006269
# f2_f2_head_significant_strikes_percent_avg      0.006121
# f2_total_strikes_percent_avg_diff               0.006094
# f2_distance_strikes_landed_diff_avg             0.006088
# f1_significant_strikes_attempts_diff_avg        0.006051
# f1_head_significant_strikes_landed_diff_avg     0.005722
# f2_head_total_strikes_landed_diff_avg           0.005656
# f1_head_significant_strikes_percent_diff_avg    0.005411
# f2_head_significant_strikes_attempts_diff_avg   0.005198
# f1_head_total_strikes_percent_diff_avg          0.005022
# f2_distance_head_strikes_percent_diff_avg       0.004992
# reach_diff                                      0.004909
# f1_distance_strikes_attempts_diff_avg           0.004839
# ...                                                  ...
# f2_f2_ground_head_strikes_attempts_avg          0.000232
# f1_f2_clinch_leg_strikes_percent_avg            0.000226
# f1_f2_significant_strikes_attempts_avg          0.000220
# f1_weight                                       0.000213
# f2_distance_leg_strikes_landed_diff_avg         0.000213
# f2_height_weight_ratio                          0.000212
# f1_clinch_significant_strikes_percent_avg_diff  0.000202
# f2_clinch_leg_strikes_attempts_avg_diff         0.000196
# f2_distance_body_strikes_percent_avg_diff       0.000195
# f1_ground_leg_strikes_attempts_diff_avg         0.000191
# f2_stance                                       0.000176
# f2_knock_down_landed_avg_diff                   0.000176
# f1_f2_ground_leg_strikes_percent_avg            0.000163
# ground_leg_strikes_landed_diff_avg_diff         0.000157
# f2_ground_body_strikes_percent_avg_diff         0.000143
# f2_f2_ground_leg_strikes_landed_avg             0.000134
# f1_f2_knock_down_landed_avg                     0.000132
# f1_f1_clinch_leg_strikes_percent_avg            0.000122
# f2_f1_ground_leg_strikes_percent_avg            0.000117
# f2_f1_ground_leg_strikes_attempts_avg           0.000116
# stance_diff                                     0.000113
# f1_clinch_leg_strikes_percent_avg_diff          0.000100
# f2_ground_leg_strikes_landed_avg_diff           0.000073
# f2_grappling_standups_landed_diff_avg           0.000068
# f2_f2_ground_leg_strikes_percent_avg            0.000031
# f1_legs_total_strikes_percent_avg_diff          0.000030
# f1_stance                                       0.000000
# ground_leg_strikes_attempts_diff_avg_diff       0.000000
# f2_ground_body_strikes_attempts_avg_diff        0.000000
# f2_ground_leg_strikes_percent_avg_diff          0.000000
#
# [666 rows x 1 columns]

# %%
ada = AdaBoostClassifier(random_state=42)
ada_params = {}
gs = GridSearchCV(ada, param_grid=ada_params)
gs.fit(X_train, y_train)
print('Best Score:', gs.best_score_)
print('Best Parameters:', gs.best_params_)
print('Test:',gs.score(X_test,y_test))
# Out:
# Best Score: 0.5336538461538461
# Best Parameters: {}
# Test: 0.5529411764705883

# %%
# %%time
gb = GradientBoostingClassifier(random_state=42)
gb_params = {
    'n_estimators': [500, 1000],
    'learning_rate': [0.05, 0.1, 0.3],
    'max_depth': [3,5]
}
gb_gs = GridSearchCV(gb, param_grid=gb_params, verbose=2, n_jobs=3 )
gb_gs.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] learning_rate=0.05, max_depth=3, n_estimators=500 ...............
# [CV] learning_rate=0.05, max_depth=3, n_estimators=500 ...............
# [CV] learning_rate=0.05, max_depth=3, n_estimators=500 ...............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=500, total=  32.8s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000 ..............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=500, total=  33.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000 ..............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=500, total=  33.6s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000 ..............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, total= 1.1min
# [CV] learning_rate=0.05, max_depth=5, n_estimators=500 ...............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, total= 1.1min
# [CV] learning_rate=0.05, max_depth=5, n_estimators=500 ...............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, total= 1.1min
# [CV] learning_rate=0.05, max_depth=5, n_estimators=500 ...............
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=500, total= 1.1min
# [CV] learning_rate=0.05, max_depth=5, n_estimators=1000 ..............
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=500, total= 1.2min
# [CV] learning_rate=0.05, max_depth=5, n_estimators=1000 ..............
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=500, total= 1.2min
# [CV] learning_rate=0.05, max_depth=5, n_estimators=1000 ..............
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=1000, total= 2.2min
# [CV] learning_rate=0.1, max_depth=3, n_estimators=500 ................
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=1000, total= 2.3min
# [CV] learning_rate=0.1, max_depth=3, n_estimators=500 ................
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=1000, total= 2.3min
# [CV] learning_rate=0.1, max_depth=3, n_estimators=500 ................
# [CV] . learning_rate=0.1, max_depth=3, n_estimators=500, total=  32.3s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=1000 ...............
# [CV] . learning_rate=0.1, max_depth=3, n_estimators=500, total=  31.5s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=1000 ...............
# [CV] . learning_rate=0.1, max_depth=3, n_estimators=500, total=  32.4s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=1000 ...............
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=1000, total= 1.1min
# [CV] learning_rate=0.1, max_depth=5, n_estimators=500 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=1000, total= 1.1min
# [CV] learning_rate=0.1, max_depth=5, n_estimators=500 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=1000, total= 1.1min
# [CV] learning_rate=0.1, max_depth=5, n_estimators=500 ................
# [CV] . learning_rate=0.1, max_depth=5, n_estimators=500, total= 1.1min
# [CV] learning_rate=0.1, max_depth=5, n_estimators=1000 ...............
# [CV] . learning_rate=0.1, max_depth=5, n_estimators=500, total= 1.2min
# [CV] learning_rate=0.1, max_depth=5, n_estimators=1000 ...............
# [CV] . learning_rate=0.1, max_depth=5, n_estimators=500, total= 1.2min
# [CV] learning_rate=0.1, max_depth=5, n_estimators=1000 ...............
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=1000, total= 1.5min
# [CV] learning_rate=0.3, max_depth=3, n_estimators=500 ................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=1000, total= 1.5min
# [CV] learning_rate=0.3, max_depth=3, n_estimators=500 ................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=1000, total= 1.5min
# [CV] learning_rate=0.3, max_depth=3, n_estimators=500 ................
# [CV] . learning_rate=0.3, max_depth=3, n_estimators=500, total=  33.0s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=1000 ...............
# [CV] . learning_rate=0.3, max_depth=3, n_estimators=500, total=  32.6s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=1000 ...............
# [CV] . learning_rate=0.3, max_depth=3, n_estimators=500, total=  32.9s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=1000 ...............
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=1000, total=  50.3s
# [CV] learning_rate=0.3, max_depth=5, n_estimators=500 ................
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=1000, total=  48.7s
# [CV] learning_rate=0.3, max_depth=5, n_estimators=500 ................
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=1000, total=  50.4s
# [CV] learning_rate=0.3, max_depth=5, n_estimators=500 ................
# [CV] . learning_rate=0.3, max_depth=5, n_estimators=500, total=  31.1s
# [CV] learning_rate=0.3, max_depth=5, n_estimators=1000 ...............
# [CV] . learning_rate=0.3, max_depth=5, n_estimators=500, total=  31.1s
# [CV] learning_rate=0.3, max_depth=5, n_estimators=1000 ...............
# [CV] . learning_rate=0.3, max_depth=5, n_estimators=500, total=  32.0s
# [CV] learning_rate=0.3, max_depth=5, n_estimators=1000 ...............
# [CV]  learning_rate=0.3, max_depth=5, n_estimators=1000, total=  31.1s
# [CV]  learning_rate=0.3, max_depth=5, n_estimators=1000, total=  31.3s
# [CV]  learning_rate=0.3, max_depth=5, n_estimators=1000, total=  32.3s
# [Parallel(n_jobs=3)]: Done  36 out of  36 | elapsed: 11.9min finished
# CPU times: user 1min 34s, sys: 394 ms, total: 1min 34s
# Wall time: 13min 26s

# %%
print('Best Score:', gs.best_score_)
print('Best Parameters:', gs.best_params_)
print('Test:',gs.score(X_test,y_test))
# Out:
# Best Score: 0.566198224852071
# Best Parameters: {'max_depth': 3, 'min_samples_split': 3, 'n_estimators': 1000}
# Test: 0.6078431372549019
