# %% [markdown]
# # 02 Process V2 Json to Fight Details

# %%
pd.options.display.max_rows = 70

# %% [markdown]
# ## Imports

# %%
import os
import json
import pandas as pd
import re
import numpy as np

# %% [markdown]
# ## Functions

# %% [markdown]
# ## TODO:
# - Rescrape, including "Ground" Stats
# - Everything is going lower case (Knock down vs. Knock Down)

# %%
def Process_All_V2_Fight_Details(rootdir):
    list_V2_fight_dicts = []
    counter = 1
    for subdir, directory, files in os.walk(rootdir):
        for file in files:
            filepath = subdir + os.sep + file
            with open(filepath) as f:
                jsn = json.load(f)
            v2_fight_dict = Process_One_V2_Fight_Details(jsn)
            if len(v2_fight_dict) > 30:
                list_V2_fight_dicts.append(v2_fight_dict)
            else:
                #print(f"Encounter short json:  {len(v2_fight_dict)}, {file}")
                v2_fight_dict = Other_Process_One_V2_Fight_Details(jsn)
                list_V2_fight_dicts.append(v2_fight_dict)

            if counter%100==0:
                print(f"{counter}: {file}")
            
            counter +=1
            
        if counter > 300000:
            break
            
    return list_V2_fight_dicts

# %%
def Other_Process_One_V2_Fight_Details(jsn):
    pass

# %%
def Process_One_V2_Fight_Details(jsn):
#   Takes a json file representing 1 fight, returns a processed dictionary
    df = pd.io.json.json_normalize(jsn)
    
    # Mask Event Round columns to avoid dropping them
    df = df.rename(columns = {'FMLiveFeed.CurrentRound':'FMLiveFeed.CurrentRnd',
                              'FMLiveFeed.CurrentRoundTime': 'FMLiveFeed.CurrentRndTime',
                              'FMLiveFeed.MaxRounds':'FMLiveFeed.MaxRnds'})

    list_words_to_drop = ['punch','kick','roundstats','type']
    list_columns_to_keep = remove_columns(df.columns, list_words_to_drop)
    df = df[list_columns_to_keep]

    # Clean up column names
    df.columns = cleanse_column_names(df.columns)
    
    # Create Dictionary
    final_dict = df.T.to_dict()[0]
    
    # Convert all keys to lowercase
    final_dict = {k.lower():v for k, v in final_dict.items()}

    return final_dict

# %%
def remove_columns(list_columns, list_words_to_drop):
#   Take in list of columns and list of words to drop.  Return list of columns with columns dropped
    list_columns_to_keep = []
    for column in list_columns:
        if not any(drop_word in column.lower() for drop_word in list_words_to_drop):
            list_columns_to_keep.append(column) 
    return list_columns_to_keep

# %%
def cleanse_column_names(list_columns_to_keep):
#   Take in "dirty" list of column names, return "clean" list of column names
    list_clean_column_names = [cleanse_column_name(column) for column in list_columns_to_keep]
    return list_clean_column_names

# %%
def cleanse_column_name(column):
#   takes in column name.  Returns cleaned up column name
    column = re.sub(' ','_', column) # Get rid of spaces
    column = re.sub('FMLiveFeed.','', column) # Get rid of FMLiveFeed
    column = re.sub('.Blue.','.F1.', column) # Get rid of Blue
    column = re.sub('.Red.','.F2.', column) # Get rid of Red
    column = re.sub('FightStats.','', column) # Get rid of FightStats
    column = re.sub('\.Strikes\.','.', column) # Get rid of Strikes
    column = re.sub('Fighters\.','', column) # Get rid of Strikes  
    column = re.sub('\.','_', column) # periods to underscores
    column = re.sub('Leg_Total_Strikes','Legs_Total_Strikes', column ) # Fix column naming error for V2a
    return column

# %%
def Other_Process_One_V2_Fight_Details(jsn):
    # Split the data into lists for easier management
    list_f1_strikes = jsn['FMLiveFeed']['FightCard']['Fight'][2]['FightStats'][0]['Fighter'][0]['Strikes']
    list_f1_grappling = jsn['FMLiveFeed']['FightCard']['Fight'][2]['FightStats'][0]['Fighter'][1]['Grappling']
    list_f1_tip = jsn['FMLiveFeed']['FightCard']['Fight'][2]['FightStats'][0]['Fighter'][2]['TIP']
    list_f2_strikes = jsn['FMLiveFeed']['FightCard']['Fight'][2]['FightStats'][1]['Fighter'][0]['Strikes']
    list_f2_grappling = jsn['FMLiveFeed']['FightCard']['Fight'][2]['FightStats'][1]['Fighter'][1]['Grappling']
    list_f2_tip = jsn['FMLiveFeed']['FightCard']['Fight'][2]['FightStats'][1]['Fighter'][2]['TIP']  

    # Create new clean dictionary
    clean_dict = {}

    # Process each dataset
    clean_dict = parse_list_strikes_tip(clean_dict, list_f1_strikes, 'F1')
    clean_dict = parse_list_grappling(clean_dict, list_f1_grappling, 'F1')
    clean_dict = parse_list_strikes_tip(clean_dict, list_f1_tip, 'F1')
    clean_dict = parse_list_strikes_tip(clean_dict, list_f2_strikes, 'F2')
    clean_dict = parse_list_grappling(clean_dict, list_f2_grappling, 'F2')
    clean_dict = parse_list_strikes_tip(clean_dict, list_f2_tip, 'F2')
    clean_dict = get_other_keys(clean_dict, jsn)
    clean_dict = add_IDs_and_names(clean_dict, jsn)
    
    # Convert all keys to lowercase
    clean_dict = {k.lower():v for k, v in clean_dict.items()}
    
    return clean_dict

# %%
def parse_list_grappling(clean_dict, list_dicts, fighter_string): 
    for one_dict in list_dicts:
        
        # Ignore any dictionary for kicks and punches (since always null)
        if 'kick' in one_dict['Name'].lower() or 'punch' in one_dict['Name'].lower():
            continue

        # Put the values into the new dictionary
        if 'Attempts' in one_dict:
            attempts_key = f"{fighter_string}_Grappling_{re.sub(' ','_',one_dict['Name'].strip())}_Attempts"
            clean_dict[attempts_key] = try_int(one_dict['Attempts'])

        if 'Landed' in one_dict:
            landed_key = f"{fighter_string}_Grappling_{re.sub(' ','_',one_dict['Name'].strip())}_Landed"
            clean_dict[landed_key] = try_int(one_dict['Landed'])

        if 'Success' in one_dict:
            landed_key = f"{fighter_string}_Grappling_{re.sub(' ','_',one_dict['Name'].strip())}_Landed"
            clean_dict[landed_key] = try_int(one_dict['Success'])  
            
    return clean_dict

# %%
def parse_list_strikes_tip(clean_dict, list_dicts, fighter_string): 
    for one_dict in list_dicts:
        
        # Ignore any dictionary for kicks and punches (since always null)
        if 'kick' in one_dict['Name'].lower() or 'punch' in one_dict['Name'].lower():
            continue

        # Put the values into the new dictionary
        if 'Attempts' in one_dict:
            attempts_key = f"{fighter_string}_{re.sub(' ','_',one_dict['Name'].strip())}_Attempts"
            clean_dict[attempts_key] = try_int(one_dict['Attempts'])

        if 'Landed' in one_dict:
            landed_key = f"{fighter_string}_{re.sub(' ','_',one_dict['Name'].strip())}_Landed"
            clean_dict[landed_key] = try_int(one_dict['Landed'])

        if 'Success' in one_dict:
            landed_key = f"{fighter_string}_{re.sub(' ','_',one_dict['Name'].strip())}_Landed"
            clean_dict[landed_key] = try_int(one_dict['Success'])  
        
        if 'Time' in one_dict:
            tip_key = f"{fighter_string}_TIP_{re.sub(' ','_',one_dict['Name'].strip())}"
            tip_key = re.sub('\.','_',tip_key)
            clean_dict[tip_key] = one_dict['Time']
            
    return clean_dict

# %%
def get_other_keys(clean_dict, jsn): 
    Other_Columns_Map = {'FMLiveFeed_FightCard_Accolade':'Accolade',
     'FMLiveFeed_FightCard_CurRound':'CurrentRnd',
     'Missing1':'CurrentRndTime',
     'FMLiveFeed_EventID':'EventID',
     'FMLiveFeed_FightCard_FightID':'FightID',
     'FMLiveFeed_FightCard_TotalNumOfRounds':'MaxRnds',
     'FMLiveFeed_FightCard_Referee':'Referee',
     'FMLiveFeed_FightCard_Status':'Status',
     'Timestamp':'Timestamp',
     'FMLiveFeed_FightCard_WeightClass':'WeightClass'}

    # Flatten the file 
    flat_jsn = flatten_json(jsn)
    
    # delete unwanted keys
    keys_to_delete = []
    for key in flat_jsn.keys():
        if 'RoundStats' in key or 'FightStats' in key or 'Fighters' in key:
            keys_to_delete.append(key)
    for key in keys_to_delete:
        del flat_jsn[key]
        
     # Append to clean_dict
    for key, value in flat_jsn.items():
        if key in Other_Columns_Map:
            clean_dict[Other_Columns_Map[key]] = value   
    
    return clean_dict

# %%
def add_IDs_and_names(clean_dict, jsn):
    name_dict = {}
    for f_dict in jsn['FMLiveFeed']['FightCard']['Fight'][0]['Fighters']:
        name_dict[f_dict['FighterID']] = f_dict['Name']
        
    f1_fighterID = jsn['FMLiveFeed']['FightCard']['Fight'][2]['FightStats'][0]['FighterID']
    f2_fighterID = jsn['FMLiveFeed']['FightCard']['Fight'][2]['FightStats'][1]['FighterID']
    
    #Add FighterIDs and Names to dictionary
    clean_dict['F1_FighterID'] = f1_fighterID
    clean_dict['F2_FighterID'] = f2_fighterID
    clean_dict['F1_Name'] = name_dict[f1_fighterID]
    clean_dict['F2_Name'] = name_dict[f2_fighterID]
    
    return clean_dict

# %%
def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# %%
def check_nulls(df):    
    return df.loc[:,df.isnull().sum()!=0].isnull().sum()

# %%
def try_int(value):
    try:
        return int(value)
         
    except:
        return value

# %% [markdown]
# ## Call my Functions and Test the Code

# %%
rootdir = '../../02_Data/01_Raw_Scraped_Data/V2_Jsons/'

# %%
list_V2_fight_dicts = Process_All_V2_Fight_Details(rootdir)
# Out:
# 100: fight_5967.json
# 200: fight_5762.json
# 300: fight_6688.json
# 400: fight_4490.json
# 500: fight_4996.json
# 600: fight_5109.json
# 700: fight_4537.json
# 800: fight_4764.json
# 900: fight_7021.json
# 1000: fight_6100.json
# 1100: fight_6187.json
# 1200: fight_5367.json
# 1300: fight_5548.json
# 1400: fight_5614.json
# 1500: fight_6634.json
# 1600: fight_6930.json
# 1700: fight_4995.json
# 1800: fight_4391.json
# 1900: fight_6399.json
# 2000: fight_7153.json
# 2100: fight_5030.json
# 2200: fight_5289.json
# 2300: fight_5428.json

# %%
df = pd.DataFrame(list_V2_fight_dicts)

# %%
df.shape
# Out:
# (2387, 140)

# %%
check_nulls(df)
# Out:
# currentrndtime    969
# dtype: int64

# %%
df.dtypes
# Out:
# accolade                                  object
# currentrnd                                object
# currentrndtime                            object
# eventid                                   object
# f1_body_significant_strikes_attempts      object
# f1_body_significant_strikes_landed        object
# f1_body_total_strikes_attempts            object
# f1_body_total_strikes_landed              object
# f1_clinch_body_strikes_attempts           object
# f1_clinch_body_strikes_landed             object
# f1_clinch_head_strikes_attempts           object
# f1_clinch_head_strikes_landed             object
# f1_clinch_leg_strikes_attempts            object
# f1_clinch_leg_strikes_landed              object
# f1_clinch_significant_strikes_attempts    object
# f1_clinch_significant_strikes_landed      object
# f1_clinch_total_strikes_attempts          object
# f1_clinch_total_strikes_landed            object
# f1_distance_body_strikes_attempts         object
# f1_distance_body_strikes_landed           object
# f1_distance_head_strikes_attempts         object
# f1_distance_head_strikes_landed           object
# f1_distance_leg_strikes_attempts          object
# f1_distance_leg_strikes_landed            object
# f1_distance_strikes_attempts              object
# f1_distance_strikes_landed                object
# f1_fighterid                              object
# f1_grappling_reversals_landed             object
# f1_grappling_standups_landed              object
# f1_grappling_submissions_attempts         object
# f1_grappling_takedowns_attempts           object
# f1_grappling_takedowns_landed             object
# f1_ground_body_strikes_attempts           object
# f1_ground_body_strikes_landed             object
# f1_ground_head_strikes_attempts           object
#                                            ...
# f2_ground_total_strikes_attempts          object
# f2_ground_total_strikes_landed            object
# f2_head_significant_strikes_attempts      object
# f2_head_significant_strikes_landed        object
# f2_head_total_strikes_attempts            object
# f2_head_total_strikes_landed              object
# f2_knock_down_landed                      object
# f2_legs_significant_strikes_attempts      object
# f2_legs_significant_strikes_landed        object
# f2_legs_total_strikes_attempts            object
# f2_legs_total_strikes_landed              object
# f2_name                                   object
# f2_significant_strikes_attempts           object
# f2_significant_strikes_landed             object
# f2_tip_back_control_time                  object
# f2_tip_clinch_time                        object
# f2_tip_control_time                       object
# f2_tip_distance_time                      object
# f2_tip_ground_control_time                object
# f2_tip_ground_time                        object
# f2_tip_guard_control_time                 object
# f2_tip_half_guard_control_time            object
# f2_tip_misc__ground_control_time          object
# f2_tip_mount_control_time                 object
# f2_tip_neutral_time                       object
# f2_tip_side_control_time                  object
# f2_tip_standing_time                      object
# f2_total_strikes_attempts                 object
# f2_total_strikes_landed                   object
# fightid                                   object
# maxrnds                                   object
# referee                                   object
# status                                    object
# timestamp                                 object
# weightclass                               object
# Length: 140, dtype: object

# %%
df.T
# Out:
#                                                         0    \
# accolade
# currentrnd                                                1
# currentrndtime                                          NaN
# eventid                                                 704
# f1_body_significant_strikes_attempts                      1
# f1_body_significant_strikes_landed                        0
# f1_body_total_strikes_attempts                            1
# f1_body_total_strikes_landed                              0
# f1_clinch_body_strikes_attempts                           0
# f1_clinch_body_strikes_landed                             0
# f1_clinch_head_strikes_attempts                           0
# f1_clinch_head_strikes_landed                             0
# f1_clinch_leg_strikes_attempts                            0
# f1_clinch_leg_strikes_landed                              0
# f1_clinch_significant_strikes_attempts                    0
# f1_clinch_significant_strikes_landed                      0
# f1_clinch_total_strikes_attempts                          0
# f1_clinch_total_strikes_landed                            0
# f1_distance_body_strikes_attempts                         1
# f1_distance_body_strikes_landed                           0
# f1_distance_head_strikes_attempts                        17
# f1_distance_head_strikes_landed                           2
# f1_distance_leg_strikes_attempts                          5
# f1_distance_leg_strikes_landed                            4
# f1_distance_strikes_attempts                             23
# f1_distance_strikes_landed                                6
# f1_fighterid                                           2239
# f1_grappling_reversals_landed                             0
# f1_grappling_standups_landed                              0
# f1_grappling_submissions_attempts                         0
# f1_grappling_takedowns_attempts                           0
# f1_grappling_takedowns_landed                             0
# f1_ground_body_strikes_attempts                           0
# f1_ground_body_strikes_landed                             0
# f1_ground_head_strikes_attempts                           0
# ...                                                     ...
# f2_ground_total_strikes_attempts                          2
# f2_ground_total_strikes_landed                            1
# f2_head_significant_strikes_attempts                     35
# f2_head_significant_strikes_landed                       11
# f2_head_total_strikes_attempts                           35
# f2_head_total_strikes_landed                             11
# f2_knock_down_landed                                      1
# f2_legs_significant_strikes_attempts                      1
# f2_legs_significant_strikes_landed                        1
# f2_legs_total_strikes_attempts                            1
# f2_legs_total_strikes_landed                              1
# f2_name                                           Joe Duffy
# f2_significant_strikes_attempts                          40
# f2_significant_strikes_landed                            15
# f2_tip_back_control_time
# f2_tip_clinch_time
# f2_tip_control_time
# f2_tip_distance_time
# f2_tip_ground_control_time
# f2_tip_ground_time
# f2_tip_guard_control_time
# f2_tip_half_guard_control_time
# f2_tip_misc__ground_control_time
# f2_tip_mount_control_time
# f2_tip_neutral_time
# f2_tip_side_control_time
# f2_tip_standing_time
# f2_total_strikes_attempts                                40
# f2_total_strikes_landed                                  15
# fightid                                                5268
# maxrnds                                                   3
# referee                                           Herb Dean
# status                                             official
# timestamp                               02:26:26 06/28/2016
# weightclass                                     Lightweight
#
#                                                           1    \
# accolade                                UFC Lightweight Title
# currentrnd                                                  5
# currentrndtime                                            NaN
# eventid                                                   704
# f1_body_significant_strikes_attempts                       37
# f1_body_significant_strikes_landed                         27
# f1_body_total_strikes_attempts                             56
# f1_body_total_strikes_landed                               45
# f1_clinch_body_strikes_attempts                             5
# f1_clinch_body_strikes_landed                               5
# f1_clinch_head_strikes_attempts                             9
# f1_clinch_head_strikes_landed                               3
# f1_clinch_leg_strikes_attempts                              3
# f1_clinch_leg_strikes_landed                                3
# f1_clinch_significant_strikes_attempts                     17
# f1_clinch_significant_strikes_landed                       11
# f1_clinch_total_strikes_attempts                           33
# f1_clinch_total_strikes_landed                             24
# f1_distance_body_strikes_attempts                          29
# f1_distance_body_strikes_landed                            20
# f1_distance_head_strikes_attempts                          78
# f1_distance_head_strikes_landed                            23
# f1_distance_leg_strikes_attempts                           17
# f1_distance_leg_strikes_landed                             15
# f1_distance_strikes_attempts                              124
# f1_distance_strikes_landed                                 58
# f1_fighterid                                              532
# f1_grappling_reversals_landed
# f1_grappling_standups_landed                                0
# f1_grappling_submissions_attempts                           0
# f1_grappling_takedowns_attempts                            10
# f1_grappling_takedowns_landed                               9
# f1_ground_body_strikes_attempts                             3
# f1_ground_body_strikes_landed                               2
# f1_ground_head_strikes_attempts                            26
# ...                                                       ...
# f2_ground_total_strikes_attempts                           35
# f2_ground_total_strikes_landed                             33
# f2_head_significant_strikes_attempts                      141
# f2_head_significant_strikes_landed                         38
# f2_head_total_strikes_attempts                            181
# f2_head_total_strikes_landed                               77
# f2_knock_down_landed                                        0
# f2_legs_significant_strikes_attempts                        5
# f2_legs_significant_strikes_landed                          5
# f2_legs_total_strikes_attempts                              5
# f2_legs_total_strikes_landed                                5
# f2_name                                        Anthony Pettis
# f2_significant_strikes_attempts                           162
# f2_significant_strikes_landed                              54
# f2_tip_back_control_time                                00:00
# f2_tip_clinch_time                                      03:56
# f2_tip_control_time                                     00:53
# f2_tip_distance_time                                    09:16
# f2_tip_ground_control_time                              00:05
# f2_tip_ground_time                                      11:52
# f2_tip_guard_control_time                               00:00
# f2_tip_half_guard_control_time                          00:00
# f2_tip_misc__ground_control_time                        00:00
# f2_tip_mount_control_time                               00:05
# f2_tip_neutral_time                                     09:35
# f2_tip_side_control_time                                00:00
# f2_tip_standing_time                                    13:12
# f2_total_strikes_attempts                                 205
# f2_total_strikes_landed                                    96
# fightid                                                  5198
# maxrnds                                                     5
# referee                                       Dan Miragliotta
# status                                               official
# timestamp                                 02:49:04 03/16/2015
# weightclass                                       Lightweight
#
#                                                         2    \
# accolade
# currentrnd                                                3
# currentrndtime                                          NaN
# eventid                                                 704
# f1_body_significant_strikes_attempts                     33
# f1_body_significant_strikes_landed                       24
# f1_body_total_strikes_attempts                           33
# f1_body_total_strikes_landed                             24
# f1_clinch_body_strikes_attempts                           2
# f1_clinch_body_strikes_landed                             2
# f1_clinch_head_strikes_attempts                           1
# f1_clinch_head_strikes_landed                             0
# f1_clinch_leg_strikes_attempts                            0
# f1_clinch_leg_strikes_landed                              0
# f1_clinch_significant_strikes_attempts                    3
# f1_clinch_significant_strikes_landed                      2
# f1_clinch_total_strikes_attempts                          3
# f1_clinch_total_strikes_landed                            2
# f1_distance_body_strikes_attempts                        31
# f1_distance_body_strikes_landed                          22
# f1_distance_head_strikes_attempts                        27
# f1_distance_head_strikes_landed                          17
# f1_distance_leg_strikes_attempts                         22
# f1_distance_leg_strikes_landed                           20
# f1_distance_strikes_attempts                             80
# f1_distance_strikes_landed                               59
# f1_fighterid                                            808
# f1_grappling_reversals_landed
# f1_grappling_standups_landed                              1
# f1_grappling_submissions_attempts                         0
# f1_grappling_takedowns_attempts                           2
# f1_grappling_takedowns_landed                             0
# f1_ground_body_strikes_attempts                           0
# f1_ground_body_strikes_landed                             0
# f1_ground_head_strikes_attempts                           1
# ...                                                     ...
# f2_ground_total_strikes_attempts                          2
# f2_ground_total_strikes_landed                            0
# f2_head_significant_strikes_attempts                     68
# f2_head_significant_strikes_landed                       18
# f2_head_total_strikes_attempts                           68
# f2_head_total_strikes_landed                             18
# f2_knock_down_landed                                      1
# f2_legs_significant_strikes_attempts                      3
# f2_legs_significant_strikes_landed                        1
# f2_legs_total_strikes_attempts                            3
# f2_legs_total_strikes_landed                              1
# f2_name                                          Roy Nelson
# f2_significant_strikes_attempts                          77
# f2_significant_strikes_landed                            23
# f2_tip_back_control_time                              00:00
# f2_tip_clinch_time                                    00:42
# f2_tip_control_time                                   00:35
# f2_tip_distance_time                                  14:15
# f2_tip_ground_control_time                            00:04
# f2_tip_ground_time                                    00:05
# f2_tip_guard_control_time                             00:00
# f2_tip_half_guard_control_time                        00:00
# f2_tip_misc__ground_control_time                      00:00
# f2_tip_mount_control_time                             00:04
# f2_tip_neutral_time                                   14:26
# f2_tip_side_control_time                              00:00
# f2_tip_standing_time                                  14:57
# f2_total_strikes_attempts                                77
# f2_total_strikes_landed                                  23
# fightid                                                5199
# maxrnds                                                   3
# referee                                           Herb Dean
# status                                             official
# timestamp                               02:49:03 03/16/2015
# weightclass                                     Heavyweight
#
#                                                         3    \
# accolade
# currentrnd                                                2
# currentrndtime                                          NaN
# eventid                                                 704
# f1_body_significant_strikes_attempts                     16
# f1_body_significant_strikes_landed                        8
# f1_body_total_strikes_attempts                           16
# f1_body_total_strikes_landed                              8
# f1_clinch_body_strikes_attempts                           1
# f1_clinch_body_strikes_landed                             1
# f1_clinch_head_strikes_attempts                           0
# f1_clinch_head_strikes_landed                             0
# f1_clinch_leg_strikes_attempts                            0
# f1_clinch_leg_strikes_landed                              0
# f1_clinch_significant_strikes_attempts                    1
# f1_clinch_significant_strikes_landed                      1
# f1_clinch_total_strikes_attempts                          1
# f1_clinch_total_strikes_landed                            1
# f1_distance_body_strikes_attempts                        15
# f1_distance_body_strikes_landed                           7
# f1_distance_head_strikes_attempts                        91
# f1_distance_head_strikes_landed                          12
# f1_distance_leg_strikes_attempts                          4
# f1_distance_leg_strikes_landed                            3
# f1_distance_strikes_attempts                            110
# f1_distance_strikes_landed                               22
# f1_fighterid                                            520
# f1_grappling_reversals_landed
# f1_grappling_standups_landed                              0
# f1_grappling_submissions_attempts                         0
# f1_grappling_takedowns_attempts                           1
# f1_grappling_takedowns_landed                             0
# f1_ground_body_strikes_attempts                           0
# f1_ground_body_strikes_landed                             0
# f1_ground_head_strikes_attempts                           0
# ...                                                     ...
# f2_ground_total_strikes_attempts                          2
# f2_ground_total_strikes_landed                            2
# f2_head_significant_strikes_attempts                     59
# f2_head_significant_strikes_landed                       16
# f2_head_total_strikes_attempts                           59
# f2_head_total_strikes_landed                             16
# f2_knock_down_landed                                      1
# f2_legs_significant_strikes_attempts                      5
# f2_legs_significant_strikes_landed                        4
# f2_legs_total_strikes_attempts                            5
# f2_legs_total_strikes_landed                              4
# f2_name                                        Ross Pearson
# f2_significant_strikes_attempts                          75
# f2_significant_strikes_landed                            25
# f2_tip_back_control_time                              00:00
# f2_tip_clinch_time                                    00:03
# f2_tip_control_time                                   00:00
# f2_tip_distance_time                                  04:58
# f2_tip_ground_control_time                            00:00
# f2_tip_ground_time                                    00:00
# f2_tip_guard_control_time                             00:00
# f2_tip_half_guard_control_time                        00:00
# f2_tip_misc__ground_control_time                      00:00
# f2_tip_mount_control_time                             00:00
# f2_tip_neutral_time                                   04:59
# f2_tip_side_control_time                              00:00
# f2_tip_standing_time                                  05:01
# f2_total_strikes_attempts                                75
# f2_total_strikes_landed                                  25
# fightid                                                5249
# maxrnds                                                   3
# referee                                     Dan Miragliotta
# status                                             official
# timestamp                               02:49:08 03/16/2015
# weightclass                                     Lightweight
#
#                                                         4    \
# accolade
# currentrnd                                                3
# currentrndtime                                          NaN
# eventid                                                 704
# f1_body_significant_strikes_attempts                      9
# f1_body_significant_strikes_landed                        7
# f1_body_total_strikes_attempts                           12
# f1_body_total_strikes_landed                             10
# f1_clinch_body_strikes_attempts                           5
# f1_clinch_body_strikes_landed                             4
# f1_clinch_head_strikes_attempts                           5
# f1_clinch_head_strikes_landed                             5
# f1_clinch_leg_strikes_attempts                            0
# f1_clinch_leg_strikes_landed                              0
# f1_clinch_significant_strikes_attempts                   10
# f1_clinch_significant_strikes_landed                      9
# f1_clinch_total_strikes_attempts                         11
# f1_clinch_total_strikes_landed                           10
# f1_distance_body_strikes_attempts                         4
# f1_distance_body_strikes_landed                           3
# f1_distance_head_strikes_attempts                        33
# f1_distance_head_strikes_landed                           9
# f1_distance_leg_strikes_attempts                          0
# f1_distance_leg_strikes_landed                            0
# f1_distance_strikes_attempts                             37
# f1_distance_strikes_landed                               12
# f1_fighterid                                            432
# f1_grappling_reversals_landed
# f1_grappling_standups_landed                              6
# f1_grappling_submissions_attempts                         0
# f1_grappling_takedowns_attempts                           0
# f1_grappling_takedowns_landed                             0
# f1_ground_body_strikes_attempts                           0
# f1_ground_body_strikes_landed                             0
# f1_ground_head_strikes_attempts                           2
# ...                                                     ...
# f2_ground_total_strikes_attempts                         81
# f2_ground_total_strikes_landed                           63
# f2_head_significant_strikes_attempts                     57
# f2_head_significant_strikes_landed                       27
# f2_head_total_strikes_attempts                          106
# f2_head_total_strikes_landed                             69
# f2_knock_down_landed                                      0
# f2_legs_significant_strikes_attempts                      5
# f2_legs_significant_strikes_landed                        4
# f2_legs_total_strikes_attempts                            7
# f2_legs_total_strikes_landed                              5
# f2_name                                     Johny Hendricks
# f2_significant_strikes_attempts                          67
# f2_significant_strikes_landed                            36
# f2_tip_back_control_time                              00:00
# f2_tip_clinch_time                                    01:29
# f2_tip_control_time                                    8:29
# f2_tip_distance_time                                  03:02
# f2_tip_ground_control_time                            10:20
# f2_tip_ground_time                                    10:32
# f2_tip_guard_control_time                             02:18
# f2_tip_half_guard_control_time                        03:13
# f2_tip_misc__ground_control_time                      00:00
# f2_tip_mount_control_time                             02:55
# f2_tip_neutral_time                                   03:24
# f2_tip_side_control_time                              01:54
# f2_tip_standing_time                                  04:31
# f2_total_strikes_attempts                               124
# f2_total_strikes_landed                                  85
# fightid                                                5245
# maxrnds                                                   3
# referee                                        Kerry Hatley
# status                                             official
# timestamp                               02:49:06 03/16/2015
# weightclass                                    Welterweight
#
#                                                         5    \
# accolade
# currentrnd                                                2
# currentrndtime                                          NaN
# eventid                                                 704
# f1_body_significant_strikes_attempts                     10
# f1_body_significant_strikes_landed                        6
# f1_body_total_strikes_attempts                           10
# f1_body_total_strikes_landed                              6
# f1_clinch_body_strikes_attempts                           0
# f1_clinch_body_strikes_landed                             0
# f1_clinch_head_strikes_attempts                           0
# f1_clinch_head_strikes_landed                             0
# f1_clinch_leg_strikes_attempts                            0
# f1_clinch_leg_strikes_landed                              0
# f1_clinch_significant_strikes_attempts                    0
# f1_clinch_significant_strikes_landed                      0
# f1_clinch_total_strikes_attempts                          1
# f1_clinch_total_strikes_landed                            1
# f1_distance_body_strikes_attempts                        10
# f1_distance_body_strikes_landed                           6
# f1_distance_head_strikes_attempts                        34
# f1_distance_head_strikes_landed                           7
# f1_distance_leg_strikes_attempts                          5
# f1_distance_leg_strikes_landed                            3
# f1_distance_strikes_attempts                             49
# f1_distance_strikes_landed                               16
# f1_fighterid                                           2252
# f1_grappling_reversals_landed
# f1_grappling_standups_landed                              1
# f1_grappling_submissions_attempts                         0
# f1_grappling_takedowns_attempts                           0
# f1_grappling_takedowns_landed                             0
# f1_ground_body_strikes_attempts                           0
# f1_ground_body_strikes_landed                             0
# f1_ground_head_strikes_attempts                           0
# ...                                                     ...
# f2_ground_total_strikes_attempts                         42
# f2_ground_total_strikes_landed                           29
# f2_head_significant_strikes_attempts                     82
# f2_head_significant_strikes_landed                       24
# f2_head_total_strikes_attempts                          104
# f2_head_total_strikes_landed                             40
# f2_knock_down_landed                                      0
# f2_legs_significant_strikes_attempts                     14
# f2_legs_significant_strikes_landed                        7
# f2_legs_total_strikes_attempts                           14
# f2_legs_total_strikes_landed                              7
# f2_name                                     Elias Theodorou
# f2_significant_strikes_attempts                         113
# f2_significant_strikes_landed                            39
# f2_tip_back_control_time                              00:00
# f2_tip_clinch_time                                    00:59
# f2_tip_control_time                                   02:15
# f2_tip_distance_time                                  06:42
# f2_tip_ground_control_time                            01:28
# f2_tip_ground_time                                    01:28
# f2_tip_guard_control_time                             00:34
# f2_tip_half_guard_control_time                        00:00
# f2_tip_misc__ground_control_time                      00:00
# f2_tip_mount_control_time                             00:52
# f2_tip_neutral_time                                   06:54
# f2_tip_side_control_time                              00:02
# f2_tip_standing_time                                  07:41
# f2_total_strikes_attempts                               135
# f2_total_strikes_landed                                  55
# fightid                                                5254
# maxrnds                                                   3
# referee                                        Kerry Hatley
# status                                             official
# timestamp                               02:52:03 03/16/2015
# weightclass                                    Middleweight
#
#                                                         6    \
# accolade
# currentrnd                                                3
# currentrndtime                                          NaN
# eventid                                                 704
# f1_body_significant_strikes_attempts                     29
# f1_body_significant_strikes_landed                       21
# f1_body_total_strikes_attempts                           44
# f1_body_total_strikes_landed                             36
# f1_clinch_body_strikes_attempts                          14
# f1_clinch_body_strikes_landed                            10
# f1_clinch_head_strikes_attempts                           3
# f1_clinch_head_strikes_landed                             2
# f1_clinch_leg_strikes_attempts                            0
# f1_clinch_leg_strikes_landed                              0
# f1_clinch_significant_strikes_attempts                   17
# f1_clinch_significant_strikes_landed                     12
# f1_clinch_total_strikes_attempts                         52
# f1_clinch_total_strikes_landed                           45
# f1_distance_body_strikes_attempts                         6
# f1_distance_body_strikes_landed                           4
# f1_distance_head_strikes_attempts                        44
# f1_distance_head_strikes_landed                          14
# f1_distance_leg_strikes_attempts                          2
# f1_distance_leg_strikes_landed                            1
# f1_distance_strikes_attempts                             52
# f1_distance_strikes_landed                               19
# f1_fighterid                                           2299
# f1_grappling_reversals_landed
# f1_grappling_standups_landed                              0
# f1_grappling_submissions_attempts                         1
# f1_grappling_takedowns_attempts                           7
# f1_grappling_takedowns_landed                             4
# f1_ground_body_strikes_attempts                           9
# f1_ground_body_strikes_landed                             7
# f1_ground_head_strikes_attempts                          15
# ...                                                     ...
# f2_ground_total_strikes_attempts                          1
# f2_ground_total_strikes_landed                            1
# f2_head_significant_strikes_attempts                     50
# f2_head_significant_strikes_landed                       11
# f2_head_total_strikes_attempts                           52
# f2_head_total_strikes_landed                             13
# f2_knock_down_landed                                      0
# f2_legs_significant_strikes_attempts                      4
# f2_legs_significant_strikes_landed                        1
# f2_legs_total_strikes_attempts                           13
# f2_legs_total_strikes_landed                              9
# f2_name                                       Chris Cariaso
# f2_significant_strikes_attempts                          71
# f2_significant_strikes_landed                            22
# f2_tip_back_control_time                              00:00
# f2_tip_clinch_time                                    04:05
# f2_tip_control_time                                   00:38
# f2_tip_distance_time                                  04:27
# f2_tip_ground_control_time                            00:00
# f2_tip_ground_time                                    06:29
# f2_tip_guard_control_time                             00:00
# f2_tip_half_guard_control_time                        00:00
# f2_tip_misc__ground_control_time                      00:00
# f2_tip_mount_control_time                             00:00
# f2_tip_neutral_time                                   04:45
# f2_tip_side_control_time                              00:00
# f2_tip_standing_time                                  08:32
# f2_total_strikes_attempts                                92
# f2_total_strikes_landed                                  41
# fightid                                                5240
# maxrnds                                                   3
# referee                                           Herb Dean
# status                                             official
# timestamp                               02:49:07 03/16/2015
# weightclass                                       Flyweight
#
#                                                         7    \
# accolade
# currentrnd                                                2
# currentrndtime                                          NaN
# eventid                                                 704
# f1_body_significant_strikes_attempts                      4
# f1_body_significant_strikes_landed                        3
# f1_body_total_strikes_attempts                            4
# f1_body_total_strikes_landed                              3
# f1_clinch_body_strikes_attempts                           0
# f1_clinch_body_strikes_landed                             0
# f1_clinch_head_strikes_attempts                           2
# f1_clinch_head_strikes_landed                             1
# f1_clinch_leg_strikes_attempts                            0
# f1_clinch_leg_strikes_landed                              0
# f1_clinch_significant_strikes_attempts                    2
# f1_clinch_significant_strikes_landed                      1
# f1_clinch_total_strikes_attempts                          2
# f1_clinch_total_strikes_landed                            1
# f1_distance_body_strikes_attempts                         4
# f1_distance_body_strikes_landed                           3
# f1_distance_head_strikes_attempts                        68
# f1_distance_head_strikes_landed                          15
# f1_distance_leg_strikes_attempts                          0
# f1_distance_leg_strikes_landed                            0
# f1_distance_strikes_attempts                             72
# f1_distance_strikes_landed                               18
# f1_fighterid                                           2134
# f1_grappling_reversals_landed
# f1_grappling_standups_landed                              1
# f1_grappling_submissions_attempts                         0
# f1_grappling_takedowns_attempts                           1
# f1_grappling_takedowns_landed                             1
# f1_ground_body_strikes_attempts                           0
# f1_ground_body_strikes_landed                             0
# f1_ground_head_strikes_attempts                          16
# ...                                                     ...
# f2_ground_total_strikes_attempts                         20
# f2_ground_total_strikes_landed                           16
# f2_head_significant_strikes_attempts                     91
# f2_head_significant_strikes_landed                       33
# f2_head_total_strikes_attempts                           96
# f2_head_total_strikes_landed                             37
# f2_knock_down_landed                                      0
# f2_legs_significant_strikes_attempts                      3
# f2_legs_significant_strikes_landed                        1
# f2_legs_total_strikes_attempts                            3
# f2_legs_total_strikes_landed                              1
# f2_name                                       Sergio Pettis
# f2_significant_strikes_attempts                         100
# f2_significant_strikes_landed                            39
# f2_tip_back_control_time                              00:00
# f2_tip_clinch_time                                    00:08
# f2_tip_control_time                                   01:34
# f2_tip_distance_time                                  04:24
# f2_tip_ground_control_time                            01:34
# f2_tip_ground_time                                    01:59
# f2_tip_guard_control_time                             00:33
# f2_tip_half_guard_control_time                        00:57
# f2_tip_misc__ground_control_time                      00:00
# f2_tip_mount_control_time                             00:04
# f2_tip_neutral_time                                   04:32
# f2_tip_side_control_time                              00:00
# f2_tip_standing_time                                  04:32
# f2_total_strikes_attempts                               113
# f2_total_strikes_landed                                  51
# fightid                                                5241
# maxrnds                                                   3
# referee                                        Kerry Hatley
# status                                             official
# timestamp                               02:52:06 03/16/2015
# weightclass                                       Flyweight
#
#                                                         8    \
# accolade
# currentrnd                                                2
# currentrndtime                                          NaN
# eventid                                                 704
# f1_body_significant_strikes_attempts                     13
# f1_body_significant_strikes_landed                       11
# f1_body_total_strikes_attempts                           14
# f1_body_total_strikes_landed                             12
# f1_clinch_body_strikes_attempts                           1
# f1_clinch_body_strikes_landed                             1
# f1_clinch_head_strikes_attempts                           4
# f1_clinch_head_strikes_landed                             1
# f1_clinch_leg_strikes_attempts                            0
# f1_clinch_leg_strikes_landed                              0
# f1_clinch_significant_strikes_attempts                    5
# f1_clinch_significant_strikes_landed                      2
# f1_clinch_total_strikes_attempts                          6
# f1_clinch_total_strikes_landed                            3
# f1_distance_body_strikes_attempts                        11
# f1_distance_body_strikes_landed                           9
# f1_distance_head_strikes_attempts                        24
# f1_distance_head_strikes_landed                           6
# f1_distance_leg_strikes_attempts                          3
# f1_distance_leg_strikes_landed                            3
# f1_distance_strikes_attempts                             38
# f1_distance_strikes_landed                               18
# f1_fighterid                                           2168
# f1_grappling_reversals_landed
# f1_grappling_standups_landed                              0
# f1_grappling_submissions_attempts                         2
# f1_grappling_takedowns_attempts                           1
# f1_grappling_takedowns_landed                             1
# f1_ground_body_strikes_attempts                           1
# f1_ground_body_strikes_landed                             1
# f1_ground_head_strikes_attempts                           7
# ...                                                     ...
# f2_ground_total_strikes_attempts                          0
# f2_ground_total_strikes_landed                            0
# f2_head_significant_strikes_attempts                     31
# f2_head_significant_strikes_landed                       10
# f2_head_total_strikes_attempts                           31
# f2_head_total_strikes_landed                             10
# f2_knock_down_landed                                      0
# f2_legs_significant_strikes_attempts                      6
# f2_legs_significant_strikes_landed                        5
# f2_legs_total_strikes_attempts                            6
# f2_legs_total_strikes_landed                              5
# f2_name                                   Daron Cruickshank
# f2_significant_strikes_attempts                          43
# f2_significant_strikes_landed                            17
# f2_tip_back_control_time                              00:00
# f2_tip_clinch_time                                    00:28
# f2_tip_control_time                                   00:18
# f2_tip_distance_time                                  04:51
# f2_tip_ground_control_time                            00:07
# f2_tip_ground_time                                    02:22
# f2_tip_guard_control_time                             00:00
# f2_tip_half_guard_control_time                        00:00
# f2_tip_misc__ground_control_time                      00:00
# f2_tip_mount_control_time                             00:07
# f2_tip_neutral_time                                   05:05
# f2_tip_side_control_time                              00:00
# f2_tip_standing_time                                  05:19
# f2_total_strikes_attempts                                44
# f2_total_strikes_landed                                  18
# fightid                                                5250
# maxrnds                                                   3
# referee                                         Don Turnage
# status                                             official
# timestamp                               03:33:50 03/18/2015
# weightclass                                     Lightweight
#
#                                                                   9    \
# accolade                                UFC Women's Strawweight Title
# currentrnd                                                          2
# currentrndtime                                                    NaN
# eventid                                                           704
# f1_body_significant_strikes_attempts                                4
# f1_body_significant_strikes_landed                                  3
# f1_body_total_strikes_attempts                                      4
# f1_body_total_strikes_landed                                        3
# f1_clinch_body_strikes_attempts                                     2
# f1_clinch_body_strikes_landed                                       1
# f1_clinch_head_strikes_attempts                                    23
# f1_clinch_head_strikes_landed                                      15
# f1_clinch_leg_strikes_attempts                                      0
# f1_clinch_leg_strikes_landed                                        0
# f1_clinch_significant_strikes_attempts                             25
# f1_clinch_significant_strikes_landed                               16
# f1_clinch_total_strikes_attempts                                   25
# f1_clinch_total_strikes_landed                                     16
# f1_distance_body_strikes_attempts                                   2
# f1_distance_body_strikes_landed                                     2
# f1_distance_head_strikes_attempts                                  73
# f1_distance_head_strikes_landed                                    30
# f1_distance_leg_strikes_attempts                                    0
# f1_distance_leg_strikes_landed                                      0
# f1_distance_strikes_attempts                                       75
# f1_distance_strikes_landed                                         32
# f1_fighterid                                                     2280
# f1_grappling_reversals_landed
# f1_grappling_standups_landed                                        1
# f1_grappling_submissions_attempts                                   0
# f1_grappling_takedowns_attempts                                     0
# f1_grappling_takedowns_landed                                       0
# f1_ground_body_strikes_attempts                                     0
# f1_ground_body_strikes_landed                                       0
# f1_ground_head_strikes_attempts                                     5
# ...                                                               ...
# f2_ground_total_strikes_attempts                                    2
# f2_ground_total_strikes_landed                                      2
# f2_head_significant_strikes_attempts                               19
# f2_head_significant_strikes_landed                                  3
# f2_head_total_strikes_attempts                                     21
# f2_head_total_strikes_landed                                        5
# f2_knock_down_landed                                                0
# f2_legs_significant_strikes_attempts                                1
# f2_legs_significant_strikes_landed                                  0
# f2_legs_total_strikes_attempts                                      1
# f2_legs_total_strikes_landed                                        0
# f2_name                                                 Carla Esparza
# f2_significant_strikes_attempts                                    22
# f2_significant_strikes_landed                                       4
# f2_tip_back_control_time                                        00:00
# f2_tip_clinch_time                                              02:24
# f2_tip_control_time                                             01:10
# f2_tip_distance_time                                            05:42
# f2_tip_ground_control_time                                      00:14
# f2_tip_ground_time                                              01:11
# f2_tip_guard_control_time                                       00:00
# f2_tip_half_guard_control_time                                  00:02
# f2_tip_misc__ground_control_time                                00:00
# f2_tip_mount_control_time                                       00:12
# f2_tip_neutral_time                                             07:01
# f2_tip_side_control_time                                        00:00
# f2_tip_standing_time                                            08:06
# f2_total_strikes_attempts                                          24
# f2_total_strikes_landed                                             6
# fightid                                                          5246
# maxrnds                                                             5
# referee                                                   Don Turnage
# status                                                       official
# timestamp                                         02:49:05 03/16/2015
# weightclass                                       Women's Strawweight
#
#                                                ...           \
# accolade                                       ...
# currentrnd                                     ...
# currentrndtime                                 ...
# eventid                                        ...
# f1_body_significant_strikes_attempts           ...
# f1_body_significant_strikes_landed             ...
# f1_body_total_strikes_attempts                 ...
# f1_body_total_strikes_landed                   ...
# f1_clinch_body_strikes_attempts                ...
# f1_clinch_body_strikes_landed                  ...
# f1_clinch_head_strikes_attempts                ...
# f1_clinch_head_strikes_landed                  ...
# f1_clinch_leg_strikes_attempts                 ...
# f1_clinch_leg_strikes_landed                   ...
# f1_clinch_significant_strikes_attempts         ...
# f1_clinch_significant_strikes_landed           ...
# f1_clinch_total_strikes_attempts               ...
# f1_clinch_total_strikes_landed                 ...
# f1_distance_body_strikes_attempts              ...
# f1_distance_body_strikes_landed                ...
# f1_distance_head_strikes_attempts              ...
# f1_distance_head_strikes_landed                ...
# f1_distance_leg_strikes_attempts               ...
# f1_distance_leg_strikes_landed                 ...
# f1_distance_strikes_attempts                   ...
# f1_distance_strikes_landed                     ...
# f1_fighterid                                   ...
# ...
# f1_ground_body_strikes_landed                             0
# f1_ground_head_strikes_attempts                           6
# ...                                                     ...
# f2_ground_total_strikes_attempts                          0
# f2_ground_total_strikes_landed                            0
# f2_head_significant_strikes_attempts                    163
# f2_head_significant_strikes_landed                       70
# f2_head_total_strikes_attempts                          165
# f2_head_total_strikes_landed                             72
# f2_knock_down_landed                                      0
# f2_legs_significant_strikes_attempts                     10
# f2_legs_significant_strikes_landed                        9
# f2_legs_total_strikes_attempts                           14
# f2_legs_total_strikes_landed                             13
# f2_name                                     Patrick Cummins
# f2_significant_strikes_attempts                         182
# f2_significant_strikes_landed                            86
# f2_tip_back_control_time                              00:02
# f2_tip_clinch_time                                    03:15
# f2_tip_control_time                                   03:07
# f2_tip_distance_time                                  11:32
# f2_tip_ground_control_time                            00:10
# f2_tip_ground_time                                    00:13
# f2_tip_guard_control_time                             00:00
# f2_tip_half_guard_control_time                        00:00
# f2_tip_misc__ground_control_time                      00:08
# f2_tip_mount_control_time                             00:00
# f2_tip_neutral_time                                   11:53
# f2_tip_side_control_time                              00:00
# f2_tip_standing_time                                  14:47
# f2_total_strikes_attempts                               188
# f2_total_strikes_landed                                  92
# fightid                                                6702
# maxrnds                                                   3
# referee                                       John McCarthy
# status                                             official
# timestamp                               03:20:39 07/24/2017
# weightclass                               Light Heavyweight
#
#                                                         298  \
# accolade
# currentrnd                                                1
# currentrndtime                                        02:18
# eventid                                                 825
# f1_body_significant_strikes_attempts                      3
# f1_body_significant_strikes_landed                        2
# f1_body_total_strikes_attempts                            3
# f1_body_total_strikes_landed                              2
# f1_clinch_body_strikes_attempts                           1
# f1_clinch_body_strikes_landed                             1
# f1_clinch_head_strikes_attempts                           0
# f1_clinch_head_strikes_landed                             0
# f1_clinch_leg_strikes_attempts                            0
# f1_clinch_leg_strikes_landed                              0
# f1_clinch_significant_strikes_attempts                    1
# f1_clinch_significant_strikes_landed                      1
# f1_clinch_total_strikes_attempts                          1
# f1_clinch_total_strikes_landed                            1
# f1_distance_body_strikes_attempts                         2
# f1_distance_body_strikes_landed                           1
# f1_distance_head_strikes_attempts                        11
# f1_distance_head_strikes_landed                           2
# f1_distance_leg_strikes_attempts                          1
# f1_distance_leg_strikes_landed                            1
# f1_distance_strikes_attempts                             14
# f1_distance_strikes_landed                                4
# f1_fighterid                                           2359
# f1_grappling_reversals_landed                             0
# f1_grappling_standups_landed                              0
# f1_grappling_submissions_attempts                         2
# f1_grappling_takedowns_attempts                           0
# f1_grappling_takedowns_landed                             0
# f1_ground_body_strikes_attempts                           0
# f1_ground_body_strikes_landed                             0
# f1_ground_head_strikes_attempts                           0
# ...                                                     ...
# f2_ground_total_strikes_attempts                          0
# f2_ground_total_strikes_landed                            0
# f2_head_significant_strikes_attempts                      7
# f2_head_significant_strikes_landed                        2
# f2_head_total_strikes_attempts                           12
# f2_head_total_strikes_landed                              7
# f2_knock_down_landed                                      0
# f2_legs_significant_strikes_attempts                      6
# f2_legs_significant_strikes_landed                        3
# f2_legs_total_strikes_attempts                            6
# f2_legs_total_strikes_landed                              3
# f2_name                                      Brian Kelleher
# f2_significant_strikes_attempts                          16
# f2_significant_strikes_landed                             8
# f2_tip_back_control_time                              00:00
# f2_tip_clinch_time                                    01:13
# f2_tip_control_time                                   01:06
# f2_tip_distance_time                                  01:01
# f2_tip_ground_control_time                            00:04
# f2_tip_ground_time                                    00:04
# f2_tip_guard_control_time                             00:00
# f2_tip_half_guard_control_time                        00:00
# f2_tip_misc__ground_control_time                      00:04
# f2_tip_mount_control_time                             00:00
# f2_tip_neutral_time                                   01:03
# f2_tip_side_control_time                              00:00
# f2_tip_standing_time                                  02:14
# f2_total_strikes_attempts                                22
# f2_total_strikes_landed                                  14
# fightid                                                6759
# maxrnds                                                   3
# referee                                      Keith Peterson
# status                                             official
# timestamp                               10:45:25 07/22/2017
# weightclass                                    Bantamweight
#
#                                                         299  \
# accolade
# currentrnd                                                3
# currentrndtime                                        05:00
# eventid                                                 825
# f1_body_significant_strikes_attempts                     20
# f1_body_significant_strikes_landed                       13
# f1_body_total_strikes_attempts                           20
# f1_body_total_strikes_landed                             13
# f1_clinch_body_strikes_attempts                           2
# f1_clinch_body_strikes_landed                             2
# f1_clinch_head_strikes_attempts                           3
# f1_clinch_head_strikes_landed                             1
# f1_clinch_leg_strikes_attempts                            2
# f1_clinch_leg_strikes_landed                              2
# f1_clinch_significant_strikes_attempts                    7
# f1_clinch_significant_strikes_landed                      5
# f1_clinch_total_strikes_attempts                          7
# f1_clinch_total_strikes_landed                            5
# f1_distance_body_strikes_attempts                        18
# f1_distance_body_strikes_landed                          11
# f1_distance_head_strikes_attempts                       118
# f1_distance_head_strikes_landed                          35
# f1_distance_leg_strikes_attempts                         24
# f1_distance_leg_strikes_landed                           21
# f1_distance_strikes_attempts                            160
# f1_distance_strikes_landed                               67
# f1_fighterid                                           2325
# f1_grappling_reversals_landed                             0
# f1_grappling_standups_landed                              4
# f1_grappling_submissions_attempts                         0
# f1_grappling_takedowns_attempts                           0
# f1_grappling_takedowns_landed                             0
# f1_ground_body_strikes_attempts                           0
# f1_ground_body_strikes_landed                             0
# f1_ground_head_strikes_attempts                           0
# ...                                                     ...
# f2_ground_total_strikes_attempts                          6
# f2_ground_total_strikes_landed                            6
# f2_head_significant_strikes_attempts                    114
# f2_head_significant_strikes_landed                       38
# f2_head_total_strikes_attempts                          117
# f2_head_total_strikes_landed                             41
# f2_knock_down_landed                                      2
# f2_legs_significant_strikes_attempts                     17
# f2_legs_significant_strikes_landed                       15
# f2_legs_total_strikes_attempts                           18
# f2_legs_total_strikes_landed                             16
# f2_name                                       Jimmie Rivera
# f2_significant_strikes_attempts                         160
# f2_significant_strikes_landed                            70
# f2_tip_back_control_time                              00:00
# f2_tip_clinch_time                                    01:22
# f2_tip_control_time                                   01:48
# f2_tip_distance_time                                  12:40
# f2_tip_ground_control_time                            00:56
# f2_tip_ground_time                                    00:56
# f2_tip_guard_control_time                             00:43
# f2_tip_half_guard_control_time                        00:00
# f2_tip_misc__ground_control_time                      00:13
# f2_tip_mount_control_time                             00:00
# f2_tip_neutral_time                                   12:54
# f2_tip_side_control_time                              00:00
# f2_tip_standing_time                                  14:02
# f2_total_strikes_attempts                               165
# f2_total_strikes_landed                                  75
# fightid                                                6688
# maxrnds                                                   3
# referee                                     Dan Miragliotta
# status                                             official
# timestamp                               03:14:44 07/24/2017
# weightclass                                    Bantamweight
#
#                                                         300
# accolade
# currentrnd                                                2
# currentrndtime                                        01:50
# eventid                                                 825
# f1_body_significant_strikes_attempts                      1
# f1_body_significant_strikes_landed                        1
# f1_body_total_strikes_attempts                            1
# f1_body_total_strikes_landed                              1
# f1_clinch_body_strikes_attempts                           1
# f1_clinch_body_strikes_landed                             1
# f1_clinch_head_strikes_attempts                           1
# f1_clinch_head_strikes_landed                             1
# f1_clinch_leg_strikes_attempts                            0
# f1_clinch_leg_strikes_landed                              0
# f1_clinch_significant_strikes_attempts                    2
# f1_clinch_significant_strikes_landed                      2
# f1_clinch_total_strikes_attempts                          2
# f1_clinch_total_strikes_landed                            2
# f1_distance_body_strikes_attempts                         0
# f1_distance_body_strikes_landed                           0
# f1_distance_head_strikes_attempts                        15
# f1_distance_head_strikes_landed                           3
# f1_distance_leg_strikes_attempts                          3
# f1_distance_leg_strikes_landed                            3
# f1_distance_strikes_attempts                             18
# f1_distance_strikes_landed                                6
# f1_fighterid                                           2469
# f1_grappling_reversals_landed                             0
# f1_grappling_standups_landed                              0
# f1_grappling_submissions_attempts                         1
# f1_grappling_takedowns_attempts                           1
# f1_grappling_takedowns_landed                             0
# f1_ground_body_strikes_attempts                           0
# f1_ground_body_strikes_landed                             0
# f1_ground_head_strikes_attempts                           1
# ...                                                     ...
# f2_ground_total_strikes_attempts                          6
# f2_ground_total_strikes_landed                            6
# f2_head_significant_strikes_attempts                     10
# f2_head_significant_strikes_landed                        2
# f2_head_total_strikes_attempts                           10
# f2_head_total_strikes_landed                              2
# f2_knock_down_landed                                      0
# f2_legs_significant_strikes_attempts                      0
# f2_legs_significant_strikes_landed                        0
# f2_legs_total_strikes_attempts                            0
# f2_legs_total_strikes_landed                              0
# f2_name                                        Ryan LaFlare
# f2_significant_strikes_attempts                          14
# f2_significant_strikes_landed                             5
# f2_tip_back_control_time                              00:13
# f2_tip_clinch_time                                    00:35
# f2_tip_control_time                                   04:07
# f2_tip_distance_time                                  02:23
# f2_tip_ground_control_time                            03:48
# f2_tip_ground_time                                    03:52
# f2_tip_guard_control_time                             00:00
# f2_tip_half_guard_control_time                        00:16
# f2_tip_misc__ground_control_time                      00:20
# f2_tip_mount_control_time                             00:00
# f2_tip_neutral_time                                   02:39
# f2_tip_side_control_time                              02:59
# f2_tip_standing_time                                  02:58
# f2_total_strikes_attempts                                17
# f2_total_strikes_landed                                   8
# fightid                                                6703
# maxrnds                                                   3
# referee                                       John McCarthy
# status                                             official
# timestamp                               03:14:37 07/24/2017
# weightclass                                    Welterweight
#
# [140 rows x 301 columns]

# %%
df.f1_grappling_reversals_landed.astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-236-7905bc8ab1ce> in <module>()
# ----> 1 df.f1_grappling_reversals_landed.astype('int64')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, **kwargs)
#    3460
#    3461     def astype(self, dtype, **kwargs):
# -> 3462         return self.apply('astype', dtype=dtype, **kwargs)
#    3463
#    3464     def convert(self, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3327
#    3328             kwargs['mgr'] = self
# -> 3329             applied = getattr(b, f)(**kwargs)
#    3330             result_blocks = _extend_blocks(applied, result_blocks)
#    3331
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     542     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     543         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 544                             **kwargs)
#     545
#     546     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     623
#     624                 # _astype_nansafe works fine with 1-d only
# --> 625                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     626                 values = values.reshape(self.shape)
#     627
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy)
#     690     elif arr.dtype == np.object_ and np.issubdtype(dtype.type, np.integer):
#     691         # work around NumPy brokenness, #1987
# --> 692         return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     693
#     694     if dtype.name in ("datetime64", "timedelta64"):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# pandas/_libs/src/util.pxd in util.set_value_at_unsafe()
#
# ValueError: invalid literal for int() with base 10: ''

# %%
df.shape
# Out:
# (2387, 140)

# %%
df.replace('', np.nan, inplace=True)

# %%
check_nulls(df)
# Out:
# accolade                            2269
# currentrndtime                       969
# f1_grappling_reversals_landed        852
# f1_tip_back_control_time             211
# f1_tip_clinch_time                   211
# f1_tip_control_time                  211
# f1_tip_distance_time                 211
# f1_tip_ground_control_time           211
# f1_tip_ground_time                   211
# f1_tip_guard_control_time            211
# f1_tip_half_guard_control_time       211
# f1_tip_misc__ground_control_time     211
# f1_tip_mount_control_time            211
# f1_tip_neutral_time                  211
# f1_tip_side_control_time             211
# f1_tip_standing_time                 211
# f2_grappling_reversals_landed        852
# f2_tip_back_control_time             211
# f2_tip_clinch_time                   211
# f2_tip_control_time                  211
# f2_tip_distance_time                 211
# f2_tip_ground_control_time           211
# f2_tip_ground_time                   211
# f2_tip_guard_control_time            211
# f2_tip_half_guard_control_time       211
# f2_tip_misc__ground_control_time     211
# f2_tip_mount_control_time            211
# f2_tip_neutral_time                  211
# f2_tip_side_control_time             211
# f2_tip_standing_time                 211
# referee                               28
# status                                15
# weightclass                           29
# dtype: int64

# %%
df[df['F2_TIP_Misc._Ground_Control_Time'].notnull()]
# Out:
#     Accolade CurrentRnd CurrentRndTime EventID FightID MaxRnds  \
# 0                     1            NaN     704    5268       3
# 16                    1            NaN     703    5202       3
# 22                    3            NaN     703    5181       3
# 54                    3            NaN     766    5962       3
# 62                    2            NaN     759    5930       3
# 75                    2            NaN     761    5872       3
# 99                    3            NaN     768    5967       3
# 105                   3            NaN     768    5959       3
# 112                   2            NaN     750    5777       3
# 121                   1            NaN     750    5733       3
# 123                   1            NaN     733    5511       3
# 135                   3            NaN     702    5171       3
# 136                   1            NaN     702    5147       3
# 137                   2            NaN     702    5146       3
# 165                   1            NaN     769    6030       3
# 166                   1            NaN     769    5978       3
# 167                   2            NaN     769    5980       3
# 199                   5            NaN     758    5762       5
# 215                   1            NaN     847    6959       3
# 227                   1            NaN     683    4936       3
# 239                   2            NaN     677    4956       3
# 252                   3            NaN     648    4621       3
# 272                   1            NaN     670    4757       3
# 280                   3            NaN     684    4982       3
#
#                 Referee    Status            Timestamp           WeightClass  \
# 0             Herb Dean  official  02:26:26 06/28/2016           Lightweight
# 16   Camila Albuquerque  official  01:42:46 11/17/2016  Women's Bantamweight
# 22       Wernei Cardoso  official  05:30:02 11/30/2015          Welterweight
# 54       Steve Perceval  official  08:00:55 02/13/2017          Welterweight
# 62            Herb Dean  official  07:02:07 09/10/2016          Bantamweight
# 75        Gary Copeland  official  04:28:42 09/19/2016           Heavyweight
# 99        Chris Tognoni  official  06:28:31 04/18/2017           Lightweight
# 105       John McCarthy  official  04:02:48 12/10/2016     Light Heavyweight
# 112       John Hosegood  official  10:01:12 04/05/2016           Heavyweight
# 121        Jorge Alonso  official  04:28:41 09/19/2016          Welterweight
# 123           Neil Hall  official  02:26:31 06/28/2016           Lightweight
# 135        Kevin Sataki  official  09:23:25 07/08/2017             Flyweight
# 136        Marc Goddard  official  10:19:38 12/05/2016     Light Heavyweight
# 137        Leon Roberts  official  03:34:15 04/05/2016           Lightweight
# 165      Grant Waterman  official  10:24:03 12/02/2017          Bantamweight
# 166        Marc Goddard  official  08:02:10 11/23/2016           Heavyweight
# 167        Kevin Sataki  official  05:51:08 11/03/2017           Heavyweight
# 199           Herb Dean  official  05:29:41 12/11/2016   Women's Strawweight
# 215   Fernando Portella  official  09:51:11 12/08/2017           Heavyweight
# 227      Keith Peterson  official  04:35:19 11/24/2017           Heavyweight
# 239        Jason Herzog  official  08:29:13 12/14/2017           Lightweight
# 252        Leon Roberts  official  08:19:16 08/29/2016           Lightweight
# 272           Herb Dean  official  07:06:51 07/11/2016           Heavyweight
# 280        Jason Herzog  official  04:26:12 05/05/2016           Lightweight
#
#               ...           F2_TIP_Ground_Time F2_TIP_Guard_Control_Time  \
# 0             ...
# 16            ...
# 22            ...
# 54            ...
# 62            ...
# 75            ...
# 99            ...
# 105           ...
# 112           ...
# 121           ...
# 123           ...
# 135           ...
# 136           ...
# 137           ...
# 165           ...
# 166           ...
# 167           ...
# 199           ...
# 215           ...
# 227           ...
# 239           ...
# 252           ...
# 272           ...
# 280           ...
#
#     F2_TIP_Half_Guard_Control_Time F2_TIP_Misc._Ground_Control_Time  \
# 0
# 16
# 22
# 54
# 62
# 75
# 99
# 105
# 112
# 121
# 123
# 135
# 136
# 137
# 165
# 166
# 167
# 199
# 215
# 227
# 239
# 252
# 272
# 280
#
#     F2_TIP_Mount_Control_Time F2_TIP_Neutral_Time F2_TIP_Side_Control_Time  \
# 0
# 16
# 22
# 54
# 62
# 75
# 99
# 105
# 112
# 121
# 123
# 135
# 136
# 137
# 165
# 166
# 167
# 199
# 215
# 227
# 239
# 252
# 272
# 280
#
#     F2_TIP_Standing_Time F2_Total_Strikes_Attempts F2_Total_Strikes_Landed
# 0                                               40                      15
# 16                                              20                       9
# 22                                             169                      46
# 54                                             250                     196
# 62                                              75                      19
# 75                                              94                      38
# 99                                             120                      61
# 105                                            100                      32
# 112                                             40                      33
# 121                                             26                      12
# 123                                             23                      13
# 135                                            160                      61
# 136                                              8                       4
# 137                                             38                       9
# 165                                            115                      87
# 166                                              8                       6
# 167                                             65                      31
# 199                                             97                      53
# 215                                             10                       4
# 227                                             32                      22
# 239                                             51                      22
# 252                                             71                      31
# 272                                             14                       6
# 280                                            190                     100
#
# [24 rows x 146 columns]

# %% [markdown]
# ## Setup Column Order: [Other Columns] [F1 Columns] [F2 Columns]

# %%
F1_Columns = [col for col in df.columns if 'f1' in col.lower()]
F2_Columns = [col for col in df.columns if 'f2' in col.lower()]
Other_Columns = [col for col in df.columns if not 'f2' in col.lower() and not 'f1' in col.lower()]


Ordered_Columns = Other_Columns + F1_Columns + F2_Columns
df = df[Ordered_Columns]

# %% [markdown]
# ## Setup subsets of columns for easy access

# %%
F1_Strikes = [col for col in F1_Columns if 'strikes' in col.lower()] + ['F1_Knock_Down_Landed']
F1_Grappling = [col for col in F1_Columns if 'grappling' in col.lower()]
F1_TIP = [col for col in F1_Columns if 'tip' in col.lower()]
F1_TIP = [col for col in F1_Columns if 'tip' in col.lower()]
F1_Identification = ['F1_FighterID','F1_Name']
F1_Identification = set(F1_Columns) - set(F1_Strikes) - set(F1_Grappling) - set(F1_TIP)

# %% [markdown]
# ## Export Data

# %%
df.to_csv('../../02_Data/02_Processed_Data/V2_Fight_Details.csv')

# %% [markdown]
# # Look at 1 JSON

# %%
rootdir = '../../02_Data/01_Raw_Scraped_Data/V2_Jsons/'

# %%
# !ls ../../02_Data/01_Raw_Scraped_Data/V2_Jsons/event_738/fight_5619.json
# Out:
# ../../02_Data/01_Raw_Scraped_Data/V2_Jsons/event_738/fight_5619.json

# %%
import json
import pandas as pd

# %%
filepath = '../../02_Data/01_Raw_Scraped_Data/V2_Jsons/event_738/fight_5619.json'
with open(filepath) as f:
    jsn = json.load(f)

# %%
final_dict = Process_One_V2_Fight_Details(jsn)

{k.lower():v for k, v in final_dict.items()}
# Out:
# {'accolade': '',
#  'currentrnd': '3',
#  'currentrndtime': '05:00',
#  'eventid': '738',
#  'f1_body_significant_strikes_attempts': '16',
#  'f1_body_significant_strikes_landed': '13',
#  'f1_body_total_strikes_attempts': '22',
#  'f1_body_total_strikes_landed': '19',
#  'f1_clinch_body_strikes_attempts': '4',
#  'f1_clinch_body_strikes_landed': '4',
#  'f1_clinch_head_strikes_attempts': '8',
#  'f1_clinch_head_strikes_landed': '3',
#  'f1_clinch_leg_strikes_attempts': '1',
#  'f1_clinch_leg_strikes_landed': '1',
#  'f1_clinch_significant_strikes_attempts': '13',
#  'f1_clinch_significant_strikes_landed': '8',
#  'f1_clinch_total_strikes_attempts': '21',
#  'f1_clinch_total_strikes_landed': '15',
#  'f1_distance_body_strikes_attempts': '12',
#  'f1_distance_body_strikes_landed': '9',
#  'f1_distance_head_strikes_attempts': '74',
#  'f1_distance_head_strikes_landed': '26',
#  'f1_distance_leg_strikes_attempts': '14',
#  'f1_distance_leg_strikes_landed': '12',
#  'f1_distance_strikes_attempts': '100',
#  'f1_distance_strikes_landed': '47',
#  'f1_fighterid': '2583',
#  'f1_grappling_reversals_landed': '0',
#  'f1_grappling_standups_landed': '1',
#  'f1_grappling_submissions_attempts': '0',
#  'f1_grappling_takedowns_attempts': '9',
#  'f1_grappling_takedowns_landed': '3',
#  'f1_ground_body_strikes_attempts': '0',
#  'f1_ground_body_strikes_landed': '0',
#  'f1_ground_head_strikes_attempts': '0',
#  'f1_ground_head_strikes_landed': '0',
#  'f1_ground_leg_strikes_attempts': '0',
#  'f1_ground_leg_strikes_landed': '0',
#  'f1_ground_significant_strikes_attempts': '0',
#  'f1_ground_significant_strikes_landed': '0',
#  'f1_ground_total_strikes_attempts': '0',
#  'f1_ground_total_strikes_landed': '0',
#  'f1_head_significant_strikes_attempts': '82',
#  'f1_head_significant_strikes_landed': '29',
#  'f1_head_total_strikes_attempts': '83',
#  'f1_head_total_strikes_landed': '30',
#  'f1_knock_down_landed': '0',
#  'f1_legs_significant_strikes_attempts': '15',
#  'f1_legs_significant_strikes_landed': '13',
#  'f1_legs_total_strikes_attempts': '16',
#  'f1_legs_total_strikes_landed': '13',
#  'f1_name': 'Sirwan Kakai',
#  'f1_significant_strikes_attempts': '113',
#  'f1_significant_strikes_landed': '55',
#  'f1_tip_back_control_time': '00:04',
#  'f1_tip_clinch_time': '03:58',
#  'f1_tip_control_time': '01:51',
#  'f1_tip_distance_time': '09:34',
#  'f1_tip_ground_control_time': '00:55',
#  'f1_tip_ground_time': '01:37',
#  'f1_tip_guard_control_time': '00:10',
#  'f1_tip_half_guard_control_time': '00:00',
#  'f1_tip_misc__ground_control_time': '00:00',
#  'f1_tip_mount_control_time': '00:41',
#  'f1_tip_neutral_time': '10:44',
#  'f1_tip_side_control_time': '00:00',
#  'f1_tip_standing_time': '13:32',
#  'f1_total_strikes_attempts': '121',
#  'f1_total_strikes_landed': '62',
#  'f2_body_significant_strikes_attempts': '32',
#  'f2_body_significant_strikes_landed': '23',
#  'f2_body_total_strikes_attempts': '33',
#  'f2_body_total_strikes_landed': '24',
#  'f2_clinch_body_strikes_attempts': '19',
#  'f2_clinch_body_strikes_landed': '14',
#  'f2_clinch_head_strikes_attempts': '27',
#  'f2_clinch_head_strikes_landed': '14',
#  'f2_clinch_leg_strikes_attempts': '3',
#  'f2_clinch_leg_strikes_landed': '3',
#  'f2_clinch_significant_strikes_attempts': '49',
#  'f2_clinch_significant_strikes_landed': '31',
#  'f2_clinch_total_strikes_attempts': '57',
#  'f2_clinch_total_strikes_landed': '39',
#  'f2_distance_body_strikes_attempts': '13',
#  'f2_distance_body_strikes_landed': '9',
#  'f2_distance_head_strikes_attempts': '109',
#  'f2_distance_head_strikes_landed': '30',
#  'f2_distance_leg_strikes_attempts': '6',
#  'f2_distance_leg_strikes_landed': '6',
#  'f2_distance_strikes_attempts': '128',
#  'f2_distance_strikes_landed': '45',
#  'f2_fighterid': '2304',
#  'f2_grappling_reversals_landed': '0',
#  'f2_grappling_standups_landed': '3',
#  'f2_grappling_submissions_attempts': '1',
#  'f2_grappling_takedowns_attempts': '6',
#  'f2_grappling_takedowns_landed': '1',
#  'f2_ground_body_strikes_attempts': '0',
#  'f2_ground_body_strikes_landed': '0',
#  'f2_ground_head_strikes_attempts': '6',
#  'f2_ground_head_strikes_landed': '4',
#  'f2_ground_leg_strikes_attempts': '0',
#  'f2_ground_leg_strikes_landed': '0',
#  'f2_ground_significant_strikes_attempts': '6',
#  'f2_ground_significant_strikes_landed': '4',
#  'f2_ground_total_strikes_attempts': '10',
#  'f2_ground_total_strikes_landed': '7',
#  'f2_head_significant_strikes_attempts': '142',
#  'f2_head_significant_strikes_landed': '48',
#  'f2_head_total_strikes_attempts': '147',
#  'f2_head_total_strikes_landed': '52',
#  'f2_knock_down_landed': '0',
#  'f2_legs_significant_strikes_attempts': '9',
#  'f2_legs_significant_strikes_landed': '9',
#  'f2_legs_total_strikes_attempts': '15',
#  'f2_legs_total_strikes_landed': '15',
#  'f2_name': 'Frankie Saenz',
#  'f2_significant_strikes_attempts': '183',
#  'f2_significant_strikes_landed': '80',
#  'f2_tip_back_control_time': '00:04',
#  'f2_tip_clinch_time': '03:58',
#  'f2_tip_control_time': '02:34',
#  'f2_tip_distance_time': '09:34',
#  'f2_tip_ground_control_time': '00:42',
#  'f2_tip_ground_time': '01:37',
#  'f2_tip_guard_control_time': '00:23',
#  'f2_tip_half_guard_control_time': '00:00',
#  'f2_tip_misc__ground_control_time': '00:00',
#  'f2_tip_mount_control_time': '00:15',
#  'f2_tip_neutral_time': '10:44',
#  'f2_tip_side_control_time': '00:00',
#  'f2_tip_standing_time': '13:32',
#  'f2_total_strikes_attempts': '195',
#  'f2_total_strikes_landed': '91',
#  'fightid': '5619',
#  'maxrnds': '3',
#  'referee': 'Herb Dean',
#  'status': 'official',
#  'timestamp': '05:20:06 08/10/2015',
#  'weightclass': 'Bantamweight'}

# %%
{k.lower(): v for k, v in alphabet.items()}

# %%
alphlower = {k.lower(): v for k, v in alphabet.iteritems()}

# %% [markdown]
# # Try to fix the First V2 Process JSON

# %% [markdown]
# What are the problems:
# - First put in "Other Process"
# - Rescrape, including "Ground" Stats
# - Fix "leg" vs. "legs" error
# - Everything is going lower case (Knock down vs. Knock Down)

# %%
F1_Leg_Total_Strikes_Attempts
F1_Leg_Total_Strikes_Landed

# %%
F1_Columns = [col for col in df.columns if 'f1' in col.lower()]
F2_Columns = [col for col in df.columns if 'f2' in col.lower()]
Other_Columns = [col for col in df.columns if not 'f2' in col.lower() and not 'f1' in col.lower()]

# %%
F1_Columns
# Out:
# ['F1_Body_Significant_Strikes_Attempts',
#  'F1_Body_Significant_Strikes_Landed',
#  'F1_Body_Total_Strikes_Attempts',
#  'F1_Body_Total_Strikes_Landed',
#  'F1_Clinch_Body_Strikes_Attempts',
#  'F1_Clinch_Body_Strikes_Landed',
#  'F1_Clinch_Head_Strikes_Attempts',
#  'F1_Clinch_Head_Strikes_Landed',
#  'F1_Clinch_Leg_Strikes_Attempts',
#  'F1_Clinch_Leg_Strikes_Landed',
#  'F1_Clinch_Significant_Strikes_Attempts',
#  'F1_Clinch_Significant_Strikes_Landed',
#  'F1_Clinch_Total_Strikes_Attempts',
#  'F1_Clinch_Total_Strikes_Landed',
#  'F1_Distance_Body_Strikes_Attempts',
#  'F1_Distance_Body_Strikes_Landed',
#  'F1_Distance_Head_Strikes_Attempts',
#  'F1_Distance_Head_Strikes_Landed',
#  'F1_Distance_Leg_Strikes_Attempts',
#  'F1_Distance_Leg_Strikes_Landed',
#  'F1_Distance_Strikes_Attempts',
#  'F1_Distance_Strikes_Landed',
#  'F1_FighterID',
#  'F1_Grappling_Reversals_Landed',
#  'F1_Grappling_Standups_Landed',
#  'F1_Grappling_Submissions_Attempts',
#  'F1_Grappling_Takedowns_Attempts',
#  'F1_Grappling_Takedowns_Landed',
#  'F1_Ground_Body_Strikes_Attempts',
#  'F1_Ground_Body_Strikes_Landed',
#  'F1_Ground_Head_Strikes_Attempts',
#  'F1_Ground_Head_Strikes_Landed',
#  'F1_Ground_Leg_Strikes_Attempts',
#  'F1_Ground_Leg_Strikes_Landed',
#  'F1_Ground_Significant_Strikes_Attempts',
#  'F1_Ground_Significant_Strikes_Landed',
#  'F1_Ground_Total_Strikes_Attempts',
#  'F1_Ground_Total_Strikes_Landed',
#  'F1_Head_Significant_Strikes_Attempts',
#  'F1_Head_Significant_Strikes_Landed',
#  'F1_Head_Total_Strikes_Attempts',
#  'F1_Head_Total_Strikes_Landed',
#  'F1_Knock_Down_Landed',
#  'F1_Knock_down_Landed',
#  'F1_Legs_Significant_Strikes_Attempts',
#  'F1_Legs_Significant_Strikes_Landed',
#  'F1_Legs_Total_Strikes_Attempts',
#  'F1_Legs_Total_Strikes_Landed',
#  'F1_Name',
#  'F1_Significant_Strikes_Attempts',
#  'F1_Significant_Strikes_Landed',
#  'F1_TIP_Back_Control_Time',
#  'F1_TIP_Clinch_Time',
#  'F1_TIP_Control_Time',
#  'F1_TIP_Distance_Time',
#  'F1_TIP_Ground_Control_Time',
#  'F1_TIP_Ground_Time',
#  'F1_TIP_Guard_Control_Time',
#  'F1_TIP_Half_Guard_Control_Time',
#  'F1_TIP_Misc._Ground_Control_Time',
#  'F1_TIP_Misc__Ground_Control_Time',
#  'F1_TIP_Mount_Control_Time',
#  'F1_TIP_Neutral_Time',
#  'F1_TIP_Side_Control_Time',
#  'F1_TIP_Standing_Time',
#  'F1_Total_Strikes_Attempts',
#  'F1_Total_Strikes_Landed']
